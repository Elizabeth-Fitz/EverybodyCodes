# %%
### Quest 1
def add(R,A):

    Result = [ R[0] + A[0], R[1] + A[1] ]
    return Result

def multiply (R,A):

    Result = [  (R[0] * A[0]) - (R[1] * A[1]),   (R[0] * A[1]) + (R[1] * A[0]) ]
    return Result


def division(R,A):

    Result = [int(R[0]/A[0]), int(R[1]/A[1])]
    return(Result)


def main ():

    R = [0,0]
    A = [164,52]


    for i in range(0,3):

        R = multiply(R,R)
        R = division(R,[10,10])
        R = add(R,A)

    print(R)

main()
# Out:
# [358648, 907718]
# [3, 2]

# %%
### Quest 2

def keep(R,x,y):
    R = [0,0]
    for i in range(0,100):
        R = multiply(R, R)
        R= division(R,[100000,100000])
        R = add(R,[x,y])


        if (R[0] > 1000000  or R[0]< -1000000) or (R[1] > 1000000  or R[1]< -1000000):
            return 0
    return 1

def main():
    A = [-4561,-68892]
    end =add(A, [1000,1000])
    counter =0
    for x in range(A[0], end[0]+1, 10):

        for y in range(A[1], end[1]+1,10):

            R = [0,0]
            counter+=keep(R,x,y)

    print(counter)


main()
# Out:
# 1246

# %%
### Quest 3

def keep(R,x,y):
    R = [0,0]
    for i in range(0,100):
        R = multiply(R, R)
        R= division(R,[100000,100000])
        R = add(R,[x,y])
        if (R[0] > 1000000  or R[0]< -1000000) or (R[1] > 1000000  or R[1]< -1000000):

            return 0

    return 1


def main():

    A=[-4561,-68892]
    end =add(A, [1000,1000])
    counter =0

    for x in range(A[0], end[0]+1):

        for y in range(A[1], end[1]+1):

            R = [0,0]
            counter+=keep(R,x,y)



    print(counter)


main()
# Out:
# 117839
