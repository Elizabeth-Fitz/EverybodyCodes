# %%
# Quest 1
# To calculate this all we need is the first and last number
# first number * 2025.
# Then take the result and divide by the last number
import math
calc = math.floor((1000 * 2025)/174)
print(calc)
# Out:
# 11637

# %%
# Quest 2
# To determine the least number, take the last number, multiply by 10000000000000
# then divide by the first number
print(math.ceil((10000000000000* 168)/931))
# Out:
# 1804511278196

# %%
# # Quest 3
# Multiply the gears in the correct order. Multiply by 100.
input = '''
545
528|528
524|524
517|517
505|1010
495|495
491|1964
482|482
479|1437
461|461
451|1804
436|436
423|423
420|420
418|1254
414|414
410|410
405|405
403|403
388|388
369|1476
361|361
348|1044
338|338
332|1328
331|331
317|634
316|316
300|300
299|299
282|846
277|277
267|1068
258|258
249|498
232|232
221|442
213|213
209|418
205|205
187|374
178|178
172|688
155|155
136|272
123|123
114|342
110|110
106|424
58
'''


i=list(input.split())
total = 1
val = i[0]
total =1

for count, each in enumerate(i):
    if count == 0:
        continue
    if '|' in each:

        x, y= each.split('|')

        total *= (int(val) / int(x))

        if '|' in each:
            val = y
    else:
        total *= ((int(val)*100)/int(i[-1]))

print(math.floor(total))
# Out:
# 478855732965
